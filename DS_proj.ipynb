# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler

print('All libraries imported successfully!')
print(f'Pandas version: {pd.__version__}')
print(f'NumPy version: {np.__version__}')
# Out:
# All libraries imported successfully!
# Pandas version: 2.2.2
# NumPy version: 2.0.2

# %%
# !pip install streamlit
import streamlit as st
import joblib
import numpy as np

# Load model and encoder
model = joblib.load('crop_recommendation_model.pkl')
le = joblib.load('label_encoder.pkl')

st.title("Crop Recommendation System")
st.write("Enter your soil and climate values to get a crop recommendation.")

# Input fields
N = st.number_input("Nitrogen (N)", min_value=0, max_value=140, value=70)
P = st.number_input("Phosphorus (P)", min_value=5, max_value=145, value=42)
K = st.number_input("Potassium (K)", min_value=5, max_value=205, value=43)
temperature = st.number_input("Temperature (°C)", min_value=8.0, max_value=44.0, value=20.8)
humidity = st.number_input("Humidity (%)", min_value=14.0, max_value=100.0, value=82.0)
ph = st.number_input("Soil pH", min_value=3.5, max_value=9.9, value=6.5)
rainfall = st.number_input("Rainfall (mm)", min_value=20.0, max_value=299.0, value=202.9)

# Predict
if st.button("Recommend Crop"):
    sample = np.array([[N, P, K, temperature, humidity, ph, rainfall]])
    prediction = model.predict(sample)
    crop = le.inverse_transform(prediction)[0]
    st.success(f"Recommended Crop: **{crop.upper()}**")
# Out:
# ...
# 2026-04-27 19:52:52.677 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 19:52:52.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 19:52:52.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 19:52:52.679 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 19:52:52.680 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 19:52:52.681 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-27 19:52:52.682 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
app_code = """
import streamlit as st
import joblib
import numpy as np

model = joblib.load('crop_recommendation_model.pkl')
le = joblib.load('label_encoder.pkl')

st.title("Crop Recommendation System")
st.write("Enter your soil and climate values to get a crop recommendation.")

N = st.number_input("Nitrogen (N)", min_value=0, max_value=140, value=70)
P = st.number_input("Phosphorus (P)", min_value=5, max_value=145, value=42)
K = st.number_input("Potassium (K)", min_value=5, max_value=205, value=43)
temperature = st.number_input("Temperature (°C)", min_value=8.0, max_value=44.0, value=20.8)
humidity = st.number_input("Humidity (%)", min_value=14.0, max_value=100.0, value=82.0)
ph = st.number_input("Soil pH", min_value=3.5, max_value=9.9, value=6.5)
rainfall = st.number_input("Rainfall (mm)", min_value=20.0, max_value=299.0, value=202.9)

if st.button("Recommend Crop"):
    sample = np.array([[N, P, K, temperature, humidity, ph, rainfall]])
    prediction = model.predict(sample)
    crop = le.inverse_transform(prediction)[0]
    st.success(f"Recommended Crop: {crop.upper()}")
"""

with open('app.py', 'w') as f:
    f.write(app_code)

print("app.py created successfully!")
# Out:
# app.py created successfully!

# %%
import os
print(os.path.exists('app.py'))                        # True
print(os.path.exists('crop_recommendation_model.pkl')) # True
print(os.path.exists('label_encoder.pkl'))             # True
# Out:
# True
# True
# True

# %%
import os

# Find exact location of all 3 files
files = ['app.py', 'crop_recommendation_model.pkl', 'label_encoder.pkl']

for f in files:
    path = os.path.abspath(f)
    exists = os.path.exists(f)
    print(f"{f}: {'✓ FOUND' if exists else '✗ NOT FOUND'} → {path}")
# Out:
# app.py: ✓ FOUND → /content/app.py
# crop_recommendation_model.pkl: ✓ FOUND → /content/crop_recommendation_model.pkl
# label_encoder.pkl: ✓ FOUND → /content/label_encoder.pkl

# %%
# !pip install pyngrok -q
from pyngrok import ngrok
import os

# Paste your token here
ngrok.set_auth_token("3CxIekIlvJ00VJQmPjS1S3K3iaz_28FvgwbUBcYQ2vGGEd8cR")

# Kill existing streamlit if any
os.system("pkill -f streamlit")

# Start streamlit
# !streamlit run /content/app.py &>/dev/null &
import time
time.sleep(3)

# Get public URL
public_url = ngrok.connect(8501)
print(f"Your app URL: {public_url}")
# Out:
# Your app URL: NgrokTunnel: "https://carve-ferocity-reboot.ngrok-free.dev" -> "http://localhost:8501"

# %%
from google.colab import drive
drive.mount('/content/drive')

import shutil
shutil.copy('/content/app.py', '/content/drive/MyDrive/app.py')
shutil.copy('/content/crop_recommendation_model.pkl', '/content/drive/MyDrive/crop_recommendation_model.pkl')
shutil.copy('/content/label_encoder.pkl', '/content/drive/MyDrive/label_encoder.pkl')
print("All files saved to Google Drive!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# All files saved to Google Drive!
